# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2 style="text-align:center;">Welcome to the third laboratory work in this course</h2>
# <h4 style="text-align:center;">This laboratory work is graded</h4>

# %% [markdown]
# <span style="color:#011f4b; font-size:15px"><b>The goal</b> of the laboratory work - is to get you familiar with pandas</b>
# <br/>
# <b>Learning outcomes:</b>
# * to be able to read data from different files
# * to use pandas to investigate data
# * to perform merging over data
# </span>
# <br/><br/>
# <span style="color:#011f4b;">
# Your task is to complete this laboratory work within 80 minutes and submit the .ipynb file to DL "Laboratory02".
# <br/>
# <b>Pay attention to the file name - your file should be named as "Laboratory_work_02_Yoursurname_YourName_yourgroup".</b> In case you didn't name your file properly (as showed before) <b>-5% penalty</b> will be applied.
# </span>

# %% [markdown]
# <hr/>

# %% [markdown]
# <b><code>pandas</code></b> is a Python package providing fast, flexible, and expressive data structures designed to make working with <strong>“relational”</strong> or <strong>“labeled”</strong> data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
# <br/>
#
# <b><code>pandas</code></b> is well suited for many different kinds of data:
#
# * Tabular data with heterogeneously-typed columns, as in an SQL table or Excel spreadsheet
#
# * Ordered and unordered (not necessarily fixed-frequency) time series data.
#
# * Arbitrary matrix data (homogeneously typed or heterogeneous) with row and column labels
#
# * Any other form of observational / statistical data sets. The data actually need not be labeled at all to be placed into a pandas data structure
# <br/>
#
# Just a few of the things that <b><code>pandas</code></b> does well:
#
#
# * Easy handling of <b>missing data</b> (represented as NaN) in floating point as well as non-floating point data
#
# * Size <b>mutability</b>: columns can be inserted and deleted from DataFrame and higher dimensional objects
#
# * Automatic and explicit <b>data alignment</b>: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
#
# * Powerful, flexible group by functionality to perform <b>split-apply-combine operations</b> on data sets, for both aggregating and transforming data
#
# * Make it <b>easy to convert</b> ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
#
# * Intelligent <b>label-based slicing</b>, fancy indexing, and subsetting of large data sets
#
# * Intuitive <b>merging and joining</b> data sets
#
# * Flexible <b>reshaping and pivoting</b> of data sets
#
# * <b>Hierarchical</b> labeling of axes (possible to have multiple labels per tick)
#
# * Robust IO tools for loading <b>data from flat files</b> (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format
#
# * <b>Time series-specific functionality</b>: date range generation and frequency conversion, moving window statistics, date shifting and lagging.

# %% [markdown]
# <hr/>

# %% [markdown]
# <b><span style="font-size:20px; color:orange">A</span>wesome</b>, now let's get started with laboratory work

# %% [markdown]
# <b>First things first,</b> import <code>pandas</code> and <code>numpy</code>packages to your notebook (you can check out [here](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html))

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+2
#     points </p>

# %%
import numpy as np

import pandas as pd

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: C:\Users\lokla\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: numpy, numpy, python-dateutil, pytz
# Required-by:

# %% [markdown]
# <b><span style="font-size:20px; color:orange">G</span>reat!</b>
# <br/>
# <b>Now</b> let's start with tasks:
# <br/>

# %% [markdown]
# <h3>TASK 1: Creation of DataFrame </h3>

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 1.1</b> Create <code>DataGrame</code> using dictionary or <code>Series</code>
# <br/>
# You can use this [help](https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html)
# <br/><br/>
# Example,

# %%
temp_series = pd.Series(np.arange(100, 49, -5), index = ['A', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'])
temp_series
# Out:
# A     100
# A      95
# A-     90
# B+     85
# B      80
# B-     75
# C+     70
# C      65
# C-     60
# D+     55
# D      50
# dtype: int32

# %%
temp_data = pd.DataFrame({'Marks' : np.arange(100, 49, -5)}, index = ['A', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'])
temp_data
# Out:
#     Marks
# A     100
# A      95
# A-     90
# B+     85
# B      80
# B-     75
# C+     70
# C      65
# C-     60
# D+     55
# D      50

# %%
# Put your solution here

# %%
# Put your solution here

# %% [markdown]
# <b>Great job!</b>
# <br/> Let's move on now
# <hr/>

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 1.2</b> DataFrame from a file
# <br/> The most convinient way to create a <code>dataframe</code> is to read data from a file.
# <br/> <code>pandas</code> allows you to read set of different files, like <i> .csv, .xlsx, .json, .txt, .html</i>
# <br/><br/>
# Example, uncomment and run the cell and eximine the code to understand

# %%
lemonade_data = pd.read_csv('Lemonade.csv')
lemonade_data.head()

# %%
lemonade_data = pd.read_csv('Lemonade.csv')
lemonade_data
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 1    02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2    03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3    04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4    05/01/2017   Thursday          NaN      1.00      33    0.3     18
# ..          ...        ...          ...       ...     ...    ...    ...
# 360  27/12/2017  Wednesday         42.7      1.00      33    0.3     19
# 361  28/12/2017   Thursday         37.8      1.25      32    0.3     16
# 362  29/12/2017     Friday         39.5      1.25      17    0.3     15
# 363  30/12/2017   Saturday         30.9      1.43      22    0.3     13
# 364  31/12/2017     Sunday         15.1      2.50       9    0.3      7
#
# [365 rows x 7 columns]

# %%
lemonade_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         365 non-null    object
#  1   Day          365 non-null    object
#  2   Temperature  360 non-null    float64
#  3   Rainfall     365 non-null    float64
#  4   Flyers       365 non-null    int64
#  5   Price        365 non-null    float64
#  6   Sales        365 non-null    int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 20.1+ KB

# %%
lemonade_data.Date = pd.to_datetime(lemonade_data.Date, dayfirst=False)

# %%
import pandas as pd

# %%
data = pd.read_csv('Lemonade.csv')

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales'], dtype='object')

# %%
data.loc[0:20, ['Date']]
# Out:
#           Date
# 0   01/01/2017
# 1   02/01/2017
# 2   03/01/2017
# 3   04/01/2017
# 4   05/01/2017
# 5   06/01/2017
# 6   07/01/2017
# 7   08/01/2017
# 8   09/01/2017
# 9   10/01/2017
# 10  11/01/2017
# 11  12/01/2017
# 12  13/01/2017
# 13  14/01/2017
# 14  15/01/2017
# 15  16/01/2017
# 16  17/01/2017
# 17  18/01/2017
# 18  19/01/2017
# 19  20/01/2017
# 20  21/01/2017

# %%
lemonade_data.head()
# Out:
#         Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0 2017-01-01     Sunday          NaN      2.00      15    0.3     10
# 1 2017-02-01     Monday          NaN      1.33      15    0.3     13
# 2 2017-03-01    Tuesday          NaN      1.33      27    0.3     15
# 3 2017-04-01  Wednesday          NaN      1.05      28    0.3     17
# 4 2017-05-01   Thursday          NaN      1.00      33    0.3     18

# %%
lemonade_data[lemonade_data.Date.dt.month==1]
# Out:
#           Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0   2017-01-01     Sunday          NaN      2.00      15    0.3     10
# 12  2017-01-13     Friday         37.5      1.33      19    0.3     15
# 13  2017-01-14   Saturday         44.1      1.05      23    0.3     17
# 14  2017-01-15     Sunday         43.4      1.11      33    0.3     18
# 15  2017-01-16     Monday         30.6      1.67      24    0.3     12
# 16  2017-01-17    Tuesday         32.2      1.43      26    0.3     14
# 17  2017-01-18  Wednesday         42.8      1.18      33    0.3     16
# 18  2017-01-19   Thursday         43.1      1.18      30    0.3     17
# 19  2017-01-20     Friday         31.6      1.43      20    0.3     12
# 20  2017-01-21   Saturday         36.2      1.25      16    0.3     14
# 21  2017-01-22     Sunday         40.8      1.11      19    0.3     16
# 22  2017-01-23     Monday         38.1      1.05      21    0.3     17
# 23  2017-01-24    Tuesday         28.6      1.54      20    0.3     12
# 24  2017-01-25  Wednesday         32.2      1.25      24    0.3     14
# 25  2017-01-26   Thursday         35.8      1.25      18    0.3     16
# 26  2017-01-27     Friday         42.1      1.05      22    0.3     17
# 27  2017-01-28   Saturday         34.9      1.33      15    0.3     13
# 28  2017-01-29     Sunday         35.2      1.33      27    0.3     14
# 29  2017-01-30     Monday         41.1      1.05      20    0.3     17
# 30  2017-01-31    Tuesday         40.4      1.05      37    0.3     18
# 31  2017-01-02  Wednesday         42.4      1.00      35    0.3     18
# 59  2017-01-03  Wednesday         57.9      0.87      46    0.3     23
# 90  2017-01-04   Saturday         57.5      0.80      33    0.3     25
# 120 2017-01-05     Monday         66.7      0.65      56    0.3     29
# 151 2017-01-06   Thursday         71.3      0.65      42    0.3     31
# 181 2017-01-07   Saturday        102.9      0.47      59    0.5     43
# 212 2017-01-08    Tuesday         75.6      0.63      56    0.5     32
# 243 2017-01-09     Friday         71.7      0.69      41    0.3     29
# 273 2017-01-10     Sunday         56.5      0.80      43    0.3     25
# 304 2017-01-11  Wednesday         51.9      0.83      43    0.3     23
# 334 2017-01-12     Friday         48.7      1.00      34    0.3     19

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 1.3</b> DataFrame from internet resource
# <br/> Sometimes your csv file located somewhere in internet
# <br/> <code>pandas</code> allows you to get data from a file in internet too
# <br/><br/>
# Example, uncomment and run the cell and eximine the code to understand

# %%
url = 'https://raw.githubusercontent.com/hxchua/datadoubleconfirm/master/datasets/arrivals2018.csv'
df = pd.read_csv(url, error_bad_lines=False)

# %%
url = 'https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv'
df = pd.read_csv(url, on_bad_lines='skip')
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102          Lex      De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 12          103    Alexander       Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 13          104        Bruce        Ernst    BERNST  590.423.4568  21-MAY-07
# 14          105        David       Austin   DAUSTIN  590.423.4569  25-JUN-05
# 15          106        Valli    Pataballa  VPATABAL  590.423.4560  05-FEB-06
# 16          107        Diana      Lorentz  DLORENTZ  590.423.5567  07-FEB-07
# 17          108        Nancy    Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 18          109       Daniel       Faviet   DFAVIET  515.124.4169  16-AUG-02
# 19          110         John         Chen     JCHEN  515.124.4269  28-SEP-05
# 20          111       Ismael      Sciarra  ISCIARRA  515.124.4369  30-SEP-05
# 21          112  Jose Manuel        Urman   JMURMAN  515.124.4469  07-MAR-06
# 22          113         Luis         Popp     LPOPP  515.124.4567  07-DEC-07
# 23          114          Den     Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
# 24          115    Alexander         Khoo     AKHOO  515.127.4562  18-MAY-03
# 25          116       Shelli        Baida    SBAIDA  515.127.4563  24-DEC-05
# 26          117        Sigal       Tobias   STOBIAS  515.127.4564  24-JUL-05
# 27          118          Guy       Himuro   GHIMURO  515.127.4565  15-NOV-06
# 28          119        Karen   Colmenares  KCOLMENA  515.127.4566  10-AUG-07
# 29          120      Matthew        Weiss    MWEISS  650.123.1234  18-JUL-04
# 30          121         Adam        Fripp    AFRIPP  650.123.2234  10-APR-05
# 31          122        Payam     Kaufling  PKAUFLIN  650.123.3234  01-MAY-03
# 32          123       Shanta      Vollman  SVOLLMAN  650.123.4234  10-OCT-05
# 33          124        Kevin      Mourgos  KMOURGOS  650.123.5234  16-NOV-07
# 34          125        Julia        Nayer    JNAYER  650.124.1214  16-JUL-05
# 35          126        Irene  Mikkilineni  IMIKKILI  650.124.1224  28-SEP-06
# 36          127        James       Landry   JLANDRY  650.124.1334  14-JAN-07
# 37          128       Steven       Markle   SMARKLE  650.124.1434  08-MAR-08
# 38          129        Laura       Bissot   LBISSOT  650.124.5234  20-AUG-05
# 39          130        Mozhe     Atkinson  MATKINSO  650.124.6234  30-OCT-05
# 40          131        James       Marlow   JAMRLOW  650.124.7234  16-FEB-05
# 41          132           TJ        Olson   TJOLSON  650.124.8234  10-APR-07
# 42          133        Jason       Mallin   JMALLIN  650.127.1934  14-JUN-04
# 43          134      Michael       Rogers   MROGERS  650.127.1834  26-AUG-06
# 44          135           Ki          Gee      KGEE  650.127.1734  12-DEC-07
# 45          136        Hazel   Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137       Renske       Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138      Stephen       Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139         John          Seo      JSEO  650.121.2019  12-FEB-06
# 49          140       Joshua        Patel    JPATEL  650.121.1834  06-APR-06
#
#         JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0     SH_CLERK    2600             -         124             50
# 1     SH_CLERK    2600             -         124             50
# 2      AD_ASST    4400             -         101             10
# 3       MK_MAN   13000             -         100             20
# 4       MK_REP    6000             -         201             20
# 5       HR_REP    6500             -         101             40
# 6       PR_REP   10000             -         101             70
# 7       AC_MGR   12008             -         101            110
# 8   AC_ACCOUNT    8300             -         205            110
# 9      AD_PRES   24000             -          -              90
# 10       AD_VP   17000             -         100             90
# 11       AD_VP   17000             -         100             90
# 12     IT_PROG    9000             -         102             60
# 13     IT_PROG    6000             -         103             60
# 14     IT_PROG    4800             -         103             60
# 15     IT_PROG    4800             -         103             60
# 16     IT_PROG    4200             -         103             60
# 17      FI_MGR   12008             -         101            100
# 18  FI_ACCOUNT    9000             -         108            100
# 19  FI_ACCOUNT    8200             -         108            100
# 20  FI_ACCOUNT    7700             -         108            100
# 21  FI_ACCOUNT    7800             -         108            100
# 22  FI_ACCOUNT    6900             -         108            100
# 23      PU_MAN   11000             -         100             30
# 24    PU_CLERK    3100             -         114             30
# 25    PU_CLERK    2900             -         114             30
# 26    PU_CLERK    2800             -         114             30
# 27    PU_CLERK    2600             -         114             30
# 28    PU_CLERK    2500             -         114             30
# 29      ST_MAN    8000             -         100             50
# 30      ST_MAN    8200             -         100             50
# 31      ST_MAN    7900             -         100             50
# 32      ST_MAN    6500             -         100             50
# 33      ST_MAN    5800             -         100             50
# 34    ST_CLERK    3200             -         120             50
# 35    ST_CLERK    2700             -         120             50
# 36    ST_CLERK    2400             -         120             50
# 37    ST_CLERK    2200             -         120             50
# 38    ST_CLERK    3300             -         121             50
# 39    ST_CLERK    2800             -         121             50
# 40    ST_CLERK    2500             -         121             50
# 41    ST_CLERK    2100             -         121             50
# 42    ST_CLERK    3300             -         122             50
# 43    ST_CLERK    2900             -         122             50
# 44    ST_CLERK    2400             -         122             50
# 45    ST_CLERK    2200             -         122             50
# 46    ST_CLERK    3600             -         123             50
# 47    ST_CLERK    3200             -         123             50
# 48    ST_CLERK    2700             -         123             50
# 49    ST_CLERK    2500             -         123             50

# %% [markdown]
# <b>Congratulations!</b>, now you can read data from the most popular file formats.
# <br/>
# Time for the next task

# %% [markdown]
# <h3> TASK 2: Inspecting your data</h3>

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 2.1 </b> Cheaking your data <u>methods</u> of dataframe as <code>head()</code> and <code>tail()</code>. For this task use the <code>lemonade_data</code> dataframe

# %%
# Don't run this cell
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1  02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3     18
# 5  06/01/2017     Friday         25.3      1.54      23    0.3     11
# 6  07/01/2017   Saturday         32.9      1.54      19    0.3     13

# %%
# Don't run this cell
# Out:
#            Date       Day  Temperature  Rainfall  Flyers  Price  Sales
# 362  29/12/2017    Friday         39.5      1.25      17    0.3     15
# 363  30/12/2017  Saturday         30.9      1.43      22    0.3     13
# 364  31/12/2017    Sunday         15.1      2.50       9    0.3      7

# %%
lemonade_data.head(7)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 1  02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2  03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3  04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4  05/01/2017   Thursday          NaN      1.00      33    0.3     18
# 5  06/01/2017     Friday         25.3      1.54      23    0.3     11
# 6  07/01/2017   Saturday         32.9      1.54      19    0.3     13

# %%
lemonade_data.tail(3)
# Out:
#            Date       Day  Temperature  Rainfall  Flyers  Price  Sales
# 362  29/12/2017    Friday         39.5      1.25      17    0.3     15
# 363  30/12/2017  Saturday         30.9      1.43      22    0.3     13
# 364  31/12/2017    Sunday         15.1      2.50       9    0.3      7

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b> Task 2.2</b>  Pandas is aware of the data types in the columns of your DataFrame. It is also aware of null and <code>NaN ('Not-a-Number')</code> types which often indicate missing data. Your job is to use <code>lemonade_data.info()</code> to determine information about the total count of non-null entries and infer the total count of <code>null</code> entries, which likely indicates missing data.

# %% [markdown]
# <b>As, our dataset <code>lemonade_data</code> has no NaNs, we will artificially add NaNs there. Run the following two cells, and proceed to the cell with the task</b>

# %%
# Run this cell
def random_nans(data_):
    data = data_.copy()
    for i in range(np.random.randint(90)):
        data.iloc[np.random.randint(365),np.random.randint(2,7)] = np.NaN
    return data

# %%
# Run this cell
lemonade_data_with_nans = random_nans(lemonade_data)
lemonade_data_with_nans
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday          NaN      2.00    15.0    0.3   10.0
# 1    02/01/2017     Monday          NaN      1.33    15.0    0.3   13.0
# 2    03/01/2017    Tuesday          NaN      1.33    27.0    0.3   15.0
# 3    04/01/2017  Wednesday          NaN      1.05    28.0    0.3   17.0
# 4    05/01/2017   Thursday          NaN      1.00    33.0    0.3   18.0
# ..          ...        ...          ...       ...     ...    ...    ...
# 360  27/12/2017  Wednesday         42.7      1.00    33.0    NaN   19.0
# 361  28/12/2017   Thursday          NaN      1.25    32.0    0.3   16.0
# 362  29/12/2017     Friday         39.5      1.25    17.0    0.3   15.0
# 363  30/12/2017   Saturday         30.9      1.43    22.0    0.3   13.0
# 364  31/12/2017     Sunday          NaN      2.50     9.0    0.3    7.0
#
# [365 rows x 7 columns]

# %%
# Using lemonade_data_with_nans dataframe and lemonade_data_with_nans.info() function 
# investigate how many null values do you have
NullSum = pd.isnull(lemonade_data_with_nans).sum()
NullSum
# Out:
# Date            0
# Day             0
# Temperature    16
# Rainfall       12
# Flyers         15
# Price          12
# Sales          10
# dtype: int64

# %% [markdown]
# # Turn this cell into markdown and write down in what columns and how many NaNs do you have
# Date            0
# Day             0
# Temperature    16
# Rainfall       12
# Flyers         15
# Price          12
# Sales          10
# dtype: int64

# %%
import pandas as pd

# %%
dt = pd.read_csv('Lemonade.csv')

# %%
dt.head(5)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 1  02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2  03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3  04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4  05/01/2017   Thursday          NaN      1.00      33    0.3     18

# %%
dt.describe().T
# Out:
#              count       mean        std    min     25%    50%    75%    max
# Temperature  360.0  61.083333  16.007289  15.10  50.225  61.15  71.70  102.9
# Rainfall     365.0   0.826603   0.273171   0.47   0.650   0.74   0.91    2.5
# Flyers       365.0  40.284932  13.178651   9.00  31.000  39.00  49.00   80.0
# Price        365.0   0.333973   0.075206   0.30   0.300   0.30   0.30    0.5
# Sales        365.0  25.323288   6.893589   7.00  20.000  25.00  30.00   43.0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         365 non-null    object
#  1   Day          365 non-null    object
#  2   Temperature  360 non-null    float64
#  3   Rainfall     365 non-null    float64
#  4   Flyers       365 non-null    int64
#  5   Price        365 non-null    float64
#  6   Sales        365 non-null    int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 20.1+ KB

# %%
dt.isnull().sum()
# Out:
# Date           0
# Day            0
# Temperature    5
# Rainfall       0
# Flyers         0
# Price          0
# Sales          0
# dtype: int64

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b> Task 2.3</b> Getting simple statistics of dataset, use <code> lemonade_data.describe()</code> to see the main statistics of you dataset

# %%
# Don't run this cell
# Out:
#              count       mean        std    min     25%    50%    75%    max
# Temperature  328.0  60.751220  16.325519  15.10  49.925  60.80  71.40  102.9
# Rainfall     327.0   0.828838   0.271606   0.47   0.650   0.77   0.91    2.5
# Flyers       329.0  40.294833  12.776503   9.00  31.000  39.00  49.00   80.0
# Price        320.0   0.335000   0.076112   0.30   0.300   0.30   0.30    0.5
# Sales        327.0  25.321101   7.055278   7.00  20.000  25.00  30.00   43.0

# %%
# Put your solution code here
lemonade_data.describe().T
# Out:
#              count       mean        std    min     25%    50%    75%    max
# Temperature  360.0  61.083333  16.007289  15.10  50.225  61.15  71.70  102.9
# Rainfall     365.0   0.826603   0.273171   0.47   0.650   0.74   0.91    2.5
# Flyers       365.0  40.284932  13.178651   9.00  31.000  39.00  49.00   80.0
# Price        365.0   0.333973   0.075206   0.30   0.300   0.30   0.30    0.5
# Sales        365.0  25.323288   6.893589   7.00  20.000  25.00  30.00   43.0

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b> Task 2.4 </b> Show the columns names  see the lecture

# %%
# Don't run this cell
# Out:
# Index(['Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales'], dtype='object')

# %%
# Put your solution code here 
lemonade_data.columns
# Out:
# Index(['Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales'], dtype='object')

# %% [markdown]
# Index(['Date', 'Day', 'Temperature', 'Rainfall', 'Flyers', 'Price', 'Sales'], dtype='object')

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b> Task 2.5 </b> Show the unique values

# %%
# Don't run this cell
# Out:
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'], dtype=object)

# %%
# Put your solution code here, find out what columns unique values these are
lemonade_data['Day'].unique()
# Out:
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'], dtype=object)

# %% [markdown]
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'], dtype=object)

# %%
# Don't run this cell
# Out:
# array([0.3, 0.5])

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %%
# Put your solution code here, find out what columns unique values these are
lemonade_data['Price'].unique()
# Out:
# array([0.3, 0.5])

# %% [markdown]
# array([0.3, 0.5])

# %% [markdown]
# <h3>TASK 3: Slicing the dataframe</h3>

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 3.1</b> Use the <code>lemonade_data.loc()</code> function to slice the dataframe

# %%
# Don't run this cell
# Out:
#          Date     Day  Temperature  Rainfall  Flyers  Price  Sales
# 5  06/01/2017  Friday         25.3      1.54      23    0.3     11

# %%
# Put your solution code here
lemonade_data.loc[5:5:1]
# Out:
#          Date     Day  Temperature  Rainfall  Flyers  Price  Sales
# 5  06/01/2017  Friday         25.3      1.54      23    0.3     11

# %%
# Don't run this cell
# Out:
#          Date      Day  Temperature  Rainfall  Flyers  Price  Sales
# 8  09/01/2017   Monday         38.1      1.18      20    0.3     17
# 9  10/01/2017  Tuesday         43.4      1.05      33    0.3     18

# %%
# Put your solution code here
lemonade_data.loc[8:9:1]
# Out:
#          Date      Day  Temperature  Rainfall  Flyers  Price  Sales
# 8  09/01/2017   Monday         38.1      1.18      20    0.3     17
# 9  10/01/2017  Tuesday         43.4      1.05      33    0.3     18

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %%
# Don't run this cell
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 3    04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 6    07/01/2017   Saturday         32.9      1.54      19    0.3     13
# 9    10/01/2017    Tuesday         43.4      1.05      33    0.3     18
# 12   13/01/2017     Friday         37.5      1.33      19    0.3     15
# ..          ...        ...          ...       ...     ...    ...    ...
# 351  18/12/2017     Monday         30.9      1.43      27    0.3     13
# 354  21/12/2017   Thursday         40.5      1.33      23    0.3     15
# 357  24/12/2017     Sunday         35.8      1.25      26    0.3     16
# 360  27/12/2017  Wednesday         42.7      1.00      33    0.3     19
# 363  30/12/2017   Saturday         30.9      1.43      22    0.3     13
#
# [122 rows x 7 columns]

# %%
# Put your solution code here
lemonade_data.loc[::3]
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 3    04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 6    07/01/2017   Saturday         32.9      1.54      19    0.3     13
# 9    10/01/2017    Tuesday         43.4      1.05      33    0.3     18
# 12   13/01/2017     Friday         37.5      1.33      19    0.3     15
# ..          ...        ...          ...       ...     ...    ...    ...
# 351  18/12/2017     Monday         30.9      1.43      27    0.3     13
# 354  21/12/2017   Thursday         40.5      1.33      23    0.3     15
# 357  24/12/2017     Sunday         35.8      1.25      26    0.3     16
# 360  27/12/2017  Wednesday         42.7      1.00      33    0.3     19
# 363  30/12/2017   Saturday         30.9      1.43      22    0.3     13
#
# [122 rows x 7 columns]

# %%
# Don't run this cell
# Out:
#     Temperature  Rainfall  Flyers
# 1          28.9      1.33      15
# 2          34.5      1.33      27
# 3          44.1      1.05      28
# 4          42.4      1.00      33
# 5          25.3      1.54      23
# 6          32.9      1.54      19
# 7          37.5      1.18      28
# 8          38.1      1.18      20
# 9          43.4      1.05      33
# 10         32.6      1.54      23
# 11         38.2      1.33      16
# 12         37.5      1.33      19
# 13         44.1      1.05      23
# 14         43.4      1.11      33
# 15         30.6      1.67      24
# 16         32.2      1.43      26
# 17         42.8      1.18      33
# 18         43.1      1.18      30
# 19         31.6      1.43      20

# %%
# Put your solution code here
lemonade_data.loc[1:19:1,'Temperature':'Flyers']
# Out:
#     Temperature  Rainfall  Flyers
# 1           NaN      1.33      15
# 2           NaN      1.33      27
# 3           NaN      1.05      28
# 4           NaN      1.00      33
# 5          25.3      1.54      23
# 6          32.9      1.54      19
# 7          37.5      1.18      28
# 8          38.1      1.18      20
# 9          43.4      1.05      33
# 10         32.6      1.54      23
# 11         38.2      1.33      16
# 12         37.5      1.33      19
# 13         44.1      1.05      23
# 14         43.4      1.11      33
# 15         30.6      1.67      24
# 16         32.2      1.43      26
# 17         42.8      1.18      33
# 18         43.1      1.18      30
# 19         31.6      1.43      20

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 3.2</b> Select all rows where Sales value is higher than 12, and count how many entries do you have, you will need extra tutorial for this task

# %%
# Put your solution code here
lemonade_data[lemonade_data.Sales >= 12]
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 1    02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2    03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3    04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4    05/01/2017   Thursday          NaN      1.00      33    0.3     18
# 6    07/01/2017   Saturday         32.9      1.54      19    0.3     13
# ..          ...        ...          ...       ...     ...    ...    ...
# 359  26/12/2017    Tuesday         28.9      1.43      23    0.3     13
# 360  27/12/2017  Wednesday         42.7      1.00      33    0.3     19
# 361  28/12/2017   Thursday         37.8      1.25      32    0.3     16
# 362  29/12/2017     Friday         39.5      1.25      17    0.3     15
# 363  30/12/2017   Saturday         30.9      1.43      22    0.3     13
#
# [360 rows x 7 columns]

# %%
# Put your solution code here
len(lemonade_data[lemonade_data.Sales >= 12])
# Out:
# 360

# %% [markdown]
# <h3>TASK 4: Manipulating dataframes </h3>

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+7 points </p>

# %% [markdown]
# <b>Task 4.1</b> Merge 2 dataframes and explore how <code>lemonade_data.merge()</code> works, for this task you can create Lemonade_01.csv

# %%
# Put your solution code here
lemonade01_data = pd.read_csv('Lemonade01.csv')
lemonade01_data.Date = pd.to_datetime(lemonade01_data.Date, dayfirst=True)

# %%
# Put your solution code here
lemonade01_data = lemonade01_data.merge(lemonade_data,how = 'outer')
lemonade01_data

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+7 points </p>

# %% [markdown]
# <b>Task 4.3</b> Add a new column called Revenew = Sales *Price

# %%
# Put your solution code here
lemonade01_data['Revenew'] = lemonade01_data.Price * lemonade01_data.Sales

# %%
# Put your solution code here
lemonade01_data
# Out:
#           Date        Day  Temperature  Rainfall  Flyers  Price  Sales  \
# 0   2017-01-01     Sunday          NaN      2.00      15    0.3     10
# 1   2017-01-02     Monday          NaN      1.33      15    0.3     13
# 2   2017-01-03    Tuesday          NaN      1.33      27    0.3     15
# 3   2017-01-04  Wednesday          NaN      1.05      28    0.3     17
# 4   2017-01-05   Thursday          NaN      1.00      33    0.3     18
# ..         ...        ...          ...       ...     ...    ...    ...
# 360 2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 361 2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 362 2017-12-29     Friday         39.5      1.25      17    0.3     15
# 363 2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 364 2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
#      Revenew
# 0        3.0
# 1        3.9
# 2        4.5
# 3        5.1
# 4        5.4
# ..       ...
# 360      5.7
# 361      4.8
# 362      4.5
# 363      3.9
# 364      2.1
#
# [365 rows x 8 columns]

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5 points </p>

# %% [markdown]
# <b>Task 4.4</b> Delete the new added column

# %%
# Put your solution code here
lemonade01_data = lemonade01_data.drop(['Revenew'], axis=1)

# %%
# Put your solution code here
lemonade01_data
# Out:
#           Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0   2017-01-01     Sunday          NaN      2.00      15    0.3     10
# 1   2017-01-02     Monday          NaN      1.33      15    0.3     13
# 2   2017-01-03    Tuesday          NaN      1.33      27    0.3     15
# 3   2017-01-04  Wednesday          NaN      1.05      28    0.3     17
# 4   2017-01-05   Thursday          NaN      1.00      33    0.3     18
# ..         ...        ...          ...       ...     ...    ...    ...
# 360 2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 361 2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 362 2017-12-29     Friday         39.5      1.25      17    0.3     15
# 363 2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 364 2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
# [365 rows x 7 columns]

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+7 points </p>

# %% [markdown]
# <h3>TASK 5: Groupping the values</h3

# %% [markdown]
# <b>Task 5.1</b>

# %%
# Don't run this cell
# Out:
# Day
# Friday       1320
# Monday       1324
# Saturday     1318
# Sunday       1316
# Thursday     1335
# Tuesday      1307
# Wednesday    1323
# Name: Sales, dtype: int64

# %%
# Put your solution code here, hint use the function pd.DataFrame.groupby() with aggregation function sum()
GrVal = lemonade_data.groupby('Day')
GrVal['Sales'].sum()
# Out:
# Day
# Friday       1320
# Monday       1324
# Saturday     1318
# Sunday       1316
# Thursday     1335
# Tuesday      1307
# Wednesday    1323
# Name: Sales, dtype: int64

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+7 points </p>

# %% [markdown]
# <b>Task 5.2 </b> Use the different aggregation function for grouped values

# %%
# Put your solution code here
GrVal = lemonade_data.groupby('Day')
GrVal['Price'].min()
# Out:
# Day
# Friday       0.3
# Monday       0.3
# Saturday     0.3
# Sunday       0.3
# Thursday     0.3
# Tuesday      0.3
# Wednesday    0.3
# Name: Price, dtype: float64

# %%
# Put your solution code here
GrVal = lemonade_data.groupby('Day')
GrVal['Flyers'].sum()
# Out:
# Day
# Friday       2097
# Monday       2069
# Saturday     1997
# Sunday       2137
# Thursday     2117
# Tuesday      2135
# Wednesday    2152
# Name: Flyers, dtype: int64

# %%
# Put your solution code here
GrVal = lemonade_data.groupby('Day')
GrVal['Temperature'].max()
# Out:
# Day
# Friday        99.3
# Monday       102.6
# Saturday     102.9
# Sunday        93.4
# Thursday      97.9
# Tuesday       99.3
# Wednesday     94.3
# Name: Temperature, dtype: float64

# %% [markdown]
# <b><span style="font-size:20px; color:orange">G</span>reat!</b> You did awesome job!
# <b>Now</b> go to the Quiz 02
# <br/>

# %%
dt.head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 1  02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2  03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3  04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4  05/01/2017   Thursday          NaN      1.00      33    0.3     18

# %%
dt_without_T = dt.drop('Temperature', axis = 1)

# %%
dt.dropna()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday          NaN      2.00      15    0.3     10
# 1  02/01/2017     Monday          NaN      1.33      15    0.3     13
# 2  03/01/2017    Tuesday          NaN      1.33      27    0.3     15
# 3  04/01/2017  Wednesday          NaN      1.05      28    0.3     17
# 4  05/01/2017   Thursday          NaN      1.00      33    0.3     18

# %%
dt_without_T.drop
# Out:
#            Date        Day  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday      2.00      15    0.3     10
# 1    02/01/2017     Monday      1.33      15    0.3     13
# 2    03/01/2017    Tuesday      1.33      27    0.3     15
# 3    04/01/2017  Wednesday      1.05      28    0.3     17
# 4    05/01/2017   Thursday      1.00      33    0.3     18
# ..          ...        ...       ...     ...    ...    ...
# 360  27/12/2017  Wednesday      1.00      33    0.3     19
# 361  28/12/2017   Thursday      1.25      32    0.3     16
# 362  29/12/2017     Friday      1.25      17    0.3     15
# 363  30/12/2017   Saturday      1.43      22    0.3     13
# 364  31/12/2017     Sunday      2.50       9    0.3      7
#
# [365 rows x 6 columns]

# %%
lemonade_data['Month'] = lemonade_data.Date.dt.month_name()

# %%
lemonade_data[lemonade_data.Month =='January'].groupby(['Day'])['Sales'].sum()
# Out:
# Day
# Friday        92
# Monday        75
# Saturday     112
# Sunday        83
# Thursday      64
# Tuesday       76
# Wednesday     94
# Name: Sales, dtype: int64

# %%
lemonade_data.Sales.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
